# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadraudhatul/DIF62130_A_25_2311532013_MUHAMMAD-RAUDHATUL/blob/main/Praktikum1/SimpleLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {'luas' : [6, 8, 10, 14, 18],
        'harga' : [7, 9, 13, 17.5, 18]}

df = pd.DataFrame(data)

df
# Out:
#    luas  harga
# 0     6    7.0
# 1     8    9.0
# 2    10   13.0
# 3    14   17.5
# 4    18   18.0

# %% [markdown]
# Kode ini digunakan untuk **membuat DataFrame** menggunakan pustaka `pandas`. Berikut penjelasannya:
#
# 1. **`import pandas as pd`**
#    - Mengimpor pustaka **pandas**, yang digunakan untuk manipulasi dan analisis data dalam bentuk tabel (DataFrame).
#
# 2. **`data = {'luas': [6, 8, 10, 14, 18], 'harga': [7, 9, 13, 17.5, 18]}`**
#    - Membuat dictionary `data` dengan dua kolom:
#      - **`'luas'`** → Menyimpan nilai ukuran luas dalam daftar `[6, 8, 10, 14, 18]`.
#      - **`'harga'`** → Menyimpan harga dalam daftar `[7, 9, 13, 17.5, 18]`.
#
# 3. **`df = pd.DataFrame(data)`**
#    - Mengonversi dictionary `data` menjadi DataFrame `df`.
#    - Struktur ini menyerupai tabel dengan dua kolom (`luas` dan `harga`).
#
# 4. **`df`**
#    - Menampilkan DataFrame yang telah dibuat.

# %%
import matplotlib.pyplot as plt

df.plot(kind='scatter', x='luas', y='harga')
plt.title('Perbandingan Luas Tanah dengan Harga Tanah')
plt.xlabel('Luas Tanah (m persegi)')
plt.ylabel('Harga Tanah (dollar)')
plt.xlim(0, 25)
plt.ylim(0, 25)
plt.grid(True)
plt.show()

# %% [markdown]
# Kode ini digunakan untuk **membuat scatter plot** yang memvisualisasikan hubungan antara **luas tanah** dan **harga tanah**.
#
# - `df.plot(kind='scatter', x='luas', y='harga')` → Membuat scatter plot dengan **luas tanah sebagai sumbu-x** dan **harga sebagai sumbu-y**.
# - `plt.title()`, `plt.xlabel()`, `plt.ylabel()` → Menambahkan judul dan label sumbu agar grafik lebih informatif.
# - `plt.xlim(0, 25)`, `plt.ylim(0, 25)` → Menentukan batas sumbu untuk memperjelas tampilan.
# - `plt.grid(True)` → Menambahkan garis grid agar lebih mudah membaca grafik.
# - `plt.show()` → Menampilkan plot yang telah dibuat.

# %%
import numpy as np
X=np.array(df['luas'])
y=np.array(df['harga'])

print(f'X: {X}')
print(f'y: {y}')
# Out:
# X: [ 6  8 10 14 18]
# y: [ 7.   9.  13.  17.5 18. ]

# %% [markdown]
# Kode ini digunakan untuk **mengonversi kolom DataFrame menjadi array NumPy** agar lebih mudah digunakan dalam operasi matematika dan Machine Learning.
#
# - `X = np.array(df['luas'])` → Mengubah kolom **'luas'** menjadi array NumPy (`X`), yang mewakili fitur (independent variable).
# - `y = np.array(df['harga'])` → Mengubah kolom **'harga'** menjadi array NumPy (`y`), yang mewakili target (dependent variable).
# - `print(f'X: {X}')`, `print(f'y: {y}')` → Menampilkan isi array untuk memastikan konversi berhasil.

# %%
X=X.reshape(-1, 1)

print(f'X shape: {X.shape}')
print(f'X: {X}')
# Out:
# X shape: (5, 1)
# X: [[ 6]
#  [ 8]
#  [10]
#  [14]
#  [18]]

# %% [markdown]
# Kode ini digunakan untuk **mengubah bentuk array NumPy** agar sesuai dengan kebutuhan model Machine Learning, terutama dalam **regresi linear** di Scikit-Learn.
#
# - `X = X.reshape(-1, 1)` → Mengubah array 1D menjadi **array 2D dengan satu kolom**, yang diperlukan untuk model yang mengharapkan input berbentuk matriks.
# - `print(f'X shape: {X.shape}')` → Menampilkan dimensi array setelah reshape.
# - `print(f'X: {X}')` → Menampilkan array yang telah diubah bentuknya.

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# Kode ini digunakan untuk **melatih model regresi linear** menggunakan dataset luas tanah (`X`) sebagai fitur dan harga tanah (`y`) sebagai target.
#
# - `model = LinearRegression()` → Membuat objek **Linear Regression** dari Scikit-Learn.
# - `model.fit(X, y)` → Melatih model dengan **X (luas tanah)** sebagai input dan **y (harga tanah)** sebagai output.

# %%
X_vis = np.array([0, 25]).reshape(-1, 1)
y_vis = model.predict(X_vis)

# %% [markdown]
# Kode ini digunakan untuk **membuat prediksi menggunakan model regresi linear** pada rentang nilai tertentu untuk tujuan visualisasi.
#
# - `X_vis = np.array([0, 25]).reshape(-1, 1)`
#   - Membuat array dengan dua nilai **0 dan 25**, yang mewakili **rentang luas tanah** yang akan divisualisasikan.
#   - `reshape(-1, 1)` mengubah array menjadi **bentuk kolom (2D)** agar sesuai dengan input model.
#
# - `y_vis = model.predict(X_vis)`
#   - Menggunakan model regresi yang telah dilatih untuk **memprediksi harga tanah** pada **luas 0 dan 25**.
#   - Hasilnya (`y_vis`) akan berisi harga tanah yang diprediksi berdasarkan **garis regresi**.

# %%
plt.scatter(X, y)
plt.plot(X_vis, y_vis, color = 'red')

plt.title('perbandingan luas tanah dengan harga tanah')
plt.xlabel('luas tanah (m persegi)')
plt.ylabel('harga tanah (dollar)')
# plt.xlim(0, 25)
# plt.xlim(0, 25)
plt.grid(True)
plt.show()

# %% [markdown]
# Kode ini digunakan untuk **memvisualisasikan hubungan antara luas tanah dan harga tanah** serta **menampilkan garis regresi linear** yang dihasilkan dari model.
#
# - `plt.scatter(X, y)` → Membuat **scatter plot** untuk menampilkan **data asli** (luas tanah vs. harga tanah).
# - `plt.plot(X_vis, y_vis, color='red')` → Menambahkan **garis regresi linear** berdasarkan prediksi model, yang menunjukkan hubungan antara luas dan harga tanah.
# - `plt.title()`, `plt.xlabel()`, `plt.ylabel()` → Menambahkan **judul dan label sumbu** agar grafik lebih informatif.
# - `plt.grid(True)` → Menampilkan **grid** untuk memudahkan pembacaan grafik.
# - `plt.show()` → Menampilkan plot.

# %%
print (f'intercept: {model.intercept_}')
print (f'slope: {model.coef_}')
# Out:
# intercept: 1.965517241379315
# slope: [0.9762931]

# %% [markdown]
# Kode ini digunakan untuk **menampilkan parameter regresi linear**, yaitu **intercept (b₀)** dan **slope/koefisien (b₁)**.
#
# - `model.intercept_` → Menampilkan **intercept (b₀)**, yaitu **nilai harga tanah saat luas tanah = 0**.
# - `model.coef_` → Menampilkan **koefisien regresi (b₁)**, yaitu **seberapa besar perubahan harga tanah jika luas tanah bertambah 1 unit**.

# %%
luas_tanah = np.array([12, 15, 20]).reshape(-1, 1)
print(luas_tanah.shape)
luas_tanah
# Out:
# (3, 1)
# array([[12],
#        [15],
#        [20]])

# %% [markdown]
# Kode ini digunakan untuk **membuat array NumPy berisi nilai luas tanah baru** yang nantinya bisa digunakan untuk prediksi harga tanah menggunakan model regresi linear.
#
# - `luas_tanah = np.array([12, 15, 20]).reshape(-1, 1)`
#   - Membuat array dengan nilai **12, 15, dan 20** yang mewakili luas tanah baru.
#   - `reshape(-1, 1)` mengubah array menjadi **bentuk kolom (2D)** agar sesuai dengan format input model regresi.
#
# - `print(luas_tanah.shape)`
#   - Menampilkan **dimensi array** untuk memastikan bahwa array memiliki bentuk yang benar sebelum digunakan dalam prediksi.
#
# - `luas_tanah`
#   - Menampilkan isi array setelah diubah bentuknya.

# %%
harga_prediksi = model.predict(luas_tanah)
harga_prediksi
# Out:
# array([13.68103448, 16.60991379, 21.49137931])

# %% [markdown]
# Kode ini digunakan untuk **memprediksi harga tanah** berdasarkan model regresi linear yang telah dilatih.
#
# - `model.predict(luas_tanah)`
#   - Menggunakan model regresi untuk **memperkirakan harga tanah** berdasarkan nilai **luas tanah** yang diberikan (`12, 15, 20`).
#
#
# - `harga_prediksi`
#   - Menyimpan hasil prediksi harga tanah untuk **luas tanah 12, 15, dan 20**.
#   - Menampilkan hasil prediksi setelah perhitungan dilakukan.

# %%
for luas, hrg in zip(luas_tanah, harga_prediksi):
  print(f'Luas tanah {luas}: harga prediksi: {hrg}')
# Out:
# Luas tanah [12]: harga prediksi: 13.681034482758621
# Luas tanah [15]: harga prediksi: 16.609913793103445
# Luas tanah [20]: harga prediksi: 21.491379310344826

# %% [markdown]
# Kode ini digunakan untuk **menampilkan hasil prediksi harga tanah secara lebih jelas dan terstruktur**.
#
# - `for luas, hrg in zip(luas_tanah, harga_prediksi):`
#   - Menggunakan **`zip()`** untuk menggabungkan setiap pasangan nilai dari **`luas_tanah`** dan hasil prediksinya **`harga_prediksi`**.
#   - Iterasi dilakukan untuk setiap nilai luas tanah dan harga prediksi.
#
# - `print(f'Luas tanah {luas}: harga prediksi: {hrg}')`
#   - Menampilkan **luas tanah** dan **harga prediksi** dalam format yang mudah dibaca.

# %%
X_train = np.array([6,8, 10, 14, 18]).reshape(-1, 1)
y_train = np.array([7, 9, 13, 17.5, 18])

X_test = np.array([9, 9, 11, 16, 12]).reshape(-1, 1)
y_test = np.array([11, 8.5, 15, 18, 11])

# %% [markdown]
# Kode ini digunakan untuk **membagi data menjadi training set dan test set** secara manual.
#
# - `X_train` dan `y_train` → Data **pelatihan (training set)**
#   - `X_train` berisi **luas tanah** yang digunakan untuk melatih model.
#   - `y_train` berisi **harga tanah** yang sesuai dengan luas tanah di `X_train`.
#   - `reshape(-1, 1)` mengubah array menjadi bentuk kolom (2D) agar sesuai dengan input model.
#
# - `X_test` dan `y_test` → Data **pengujian (test set)**
#   - `X_test` berisi **luas tanah** yang akan diuji dalam model.
#   - `y_test` berisi **harga tanah aktual** yang akan dibandingkan dengan hasil prediksi model.

# %%
model=LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Kode ini digunakan untuk **melatih model regresi linear** menggunakan data training (`X_train`, `y_train`).
#
# - `model = LinearRegression()` → Membuat objek model **Linear Regression** dari Scikit-Learn.
# - `model.fit(X_train, y_train)` → **Melatih model** dengan **luas tanah (X_train)** sebagai input dan **harga tanah (y_train)** sebagai target.

# %%
from sklearn.metrics import r2_score

y_pred = model.predict(X_test)
r_squared = r2_score(y_test, y_pred)
print(f'R-squared: {r_squared}')
# Out:
# R-squared: 0.6873061136400747

# %% [markdown]
# Kode ini digunakan untuk **mengukur performa model regresi linear** dengan menghitung **koefisien determinasi** (\( R^2 \)).
#
# - `y_pred = model.predict(X_test)` → Menggunakan model regresi untuk **memprediksi harga tanah** berdasarkan **X_test**.
# - `r2_score(y_test, y_pred)` → Menghitung **nilai \( R^2 \)** dengan membandingkan nilai asli (`y_test`) dan nilai prediksi (`y_pred`).
# - `print(f'R-squared: {r_squared}')` → Menampilkan hasil nilai \( R^2 \).

# %%
y_pred
# Out:
# array([10.75215517, 10.75215517, 12.70474138, 17.5862069 , 13.68103448])

# %% [markdown]
# Variabel y_pred berisi hasil prediksi harga tanah berdasarkan model regresi linear yang telah dilatih.
